# %% [markdown]
# # Data Manipulation Studio
#
# For this studio, we will revisit our California farmers looking for advice on growing pumpkins and the same [pumpkins dataset](https://www.kaggle.com/usda/a-year-of-pumpkin-prices) as provided by the U.S. Department of Agriculture. You may have to clean data in the process of data manipulation, so feel free to pull up your notebook from the last class's studio.
#
# We will now be focusing our attention on a different region in the United States, the Northeast. When you open up the `dataset` folder, you will have 13 CSVs, including the San Francisco and Los Angeles data from the last lesson. The 13 CSVs are each a different terminal market in the United States.
#
# ## Getting Started
#
# Import the CSVs for each of the following cities: Baltimore, Boston, New York, and Philadelphia. Set up a dataframe for each city.

# %%
# Import the necessary libraries and CSVs. Make some dataframes!
import pandas as pd
df = pd.read_csv(r"C:\Users\16183\Downloads\philadelphia_9-24-2016_9-30-2017.csv")
df.head(10)

df2 = pd.read_csv(r"C:\Users\16183\Downloads\boston_9-24-2016_9-30-2017.csv")
df2.head(10)

df3 = pd.read_csv(r"C:\Users\16183\Downloads\baltimore_9-24-2016_9-30-2017.csv")
df3.head(10)

df4 = pd.read_csv(r"C:\Users\16183\Downloads\new-york_9-24-2016_9-30-2017.csv")
df4.head(10)
# Out:
#   Commodity Name City Name  Type       Package      Variety Sub Variety  \
# 0       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 1       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 2       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 3       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 4       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 5       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 6       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 7       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 8       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 9       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
#
#    Grade        Date  Low Price  High Price  ...  Color  Environment  \
# 0    NaN  09/24/2016        150         170  ...    NaN          NaN
# 1    NaN  09/24/2016        150         170  ...    NaN          NaN
# 2    NaN  09/24/2016        130         150  ...    NaN          NaN
# 3    NaN  09/24/2016        130         150  ...    NaN          NaN
# 4    NaN  09/24/2016        120         140  ...    NaN          NaN
# 5    NaN  09/24/2016        150         170  ...    NaN          NaN
# 6    NaN  09/24/2016        120         170  ...    NaN          NaN
# 7    NaN  09/24/2016        180         190  ...    NaN          NaN
# 8    NaN  10/01/2016        150         170  ...    NaN          NaN
# 9    NaN  10/01/2016        150         170  ...    NaN          NaN
#
#   Unit of Sale Quality Condition Appearance  Storage Crop  Repack  Trans Mode
# 0          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 1          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 2          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 3          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 4          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 5          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 6          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 7          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 8          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 9          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
#
# [10 rows x 25 columns]

# %% [markdown]
# ## Clean Your Data
#
# In the last lesson, we cleaned the data to related to San Francisco. Pull up your notebook from the last lesson and use your cleaning skills to clean the dataframes as necessary.

# %%
# Clean your data here!
import matplotlib 
import matplotlib.pyplot as plt
import numpy as np

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
    

total_cells = np.product(df.shape)

missing_cells = pd.isnull(df).sum()

total_missing = missing_cells.sum()

percentage_missing = round((total_missing/total_cells), 2) *100

print(percentage_missing, "% Missing cells from the data")   

df["Repack"] = df["Repack"].replace({"N":False})
#Check status with a quick head check
df.head(3)
df["Type"] = df["Type"].fillna("Conventional")
# Out:
# Commodity Name - 0%
# City Name - 0%
# Type - 0%
# Package - 0%
# Variety - 0%
# Sub Variety - 79%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 0%
# Origin District - 100%
# Item Size - 21%
# Color - 100%
# Environment - 100%
# Unit of Sale - 81%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%
# 45.0 % Missing cells from the data

# %%
for col in df2.columns:
    pct_missing = np.mean(df2[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
    

total_cells = np.product(df2.shape)

missing_cells = pd.isnull(df2).sum()

total_missing = missing_cells.sum()

percentage_missing = round((total_missing/total_cells), 2) *100

print(percentage_missing, "% Missing cells from the data")   

df2["Repack"] = df2["Repack"].replace({"N":False})
#Check status with a quick head check
df2.head(3)
df2["Type"] = df2["Type"].fillna("Conventional")
# Out:
# Commodity Name - 0%
# City Name - 0%
# Type - 100%
# Package - 0%
# Variety - 0%
# Sub Variety - 92%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 0%
# Origin District - 81%
# Item Size - 1%
# Color - 14%
# Environment - 100%
# Unit of Sale - 87%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%
# 47.0 % Missing cells from the data

# %%
for col in df3.columns:
    pct_missing = np.mean(df3[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
    

total_cells = np.product(df3.shape)

missing_cells = pd.isnull(df3).sum()

total_missing = missing_cells.sum()

percentage_missing = round((total_missing/total_cells), 2) *100

print(percentage_missing, "% Missing cells from the data")   

df3["Repack"] = df3["Repack"].replace({"N":False})
#Check status with a quick head check
df3.head(3)
df3["Type"] = df3["Type"].fillna("Conventional")
# Out:
# Commodity Name - 0%
# City Name - 0%
# Type - 100%
# Package - 0%
# Variety - 1%
# Sub Variety - 84%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 3%
# Origin District - 100%
# Item Size - 16%
# Color - 80%
# Environment - 100%
# Unit of Sale - 84%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%
# 51.0 % Missing cells from the data

# %%
for col in df4.columns:
    pct_missing = np.mean(df4[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
    

total_cells = np.product(df4.shape)

missing_cells = pd.isnull(df4).sum()

total_missing = missing_cells.sum()

percentage_missing = round((total_missing/total_cells), 2) *100

print(percentage_missing, "% Missing cells from the data")   

df4["Repack"] = df4["Repack"].replace({"N":False})
#Check status with a quick head check
df4.head(3)
df4["Type"] = df4["Type"].fillna("Conventional")
# Out:
# Commodity Name - 0%
# City Name - 0%
# Type - 100%
# Package - 0%
# Variety - 0%
# Sub Variety - 84%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 0%
# Origin District - 87%
# Item Size - 7%
# Color - 81%
# Environment - 100%
# Unit of Sale - 78%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%
# 49.0 % Missing cells from the data

# %% [markdown]
# ## Combine Your Data
#
# Now that you have four clean sets of data, combine all four into one dataframe that represents the entire Northeast region.

# %%
# Combine the four dataframes into one!
frames = [df, df2, df3, df4]

result = pd.concat(frames)

result
# Out:
#     Commodity Name     City Name          Type              Package  \
# 0         PUMPKINS  PHILADELPHIA  Conventional         24 inch bins
# 1         PUMPKINS  PHILADELPHIA  Conventional         36 inch bins
# 2         PUMPKINS  PHILADELPHIA  Conventional         36 inch bins
# 3         PUMPKINS  PHILADELPHIA  Conventional         36 inch bins
# 4         PUMPKINS  PHILADELPHIA  Conventional         36 inch bins
# ..             ...           ...           ...                  ...
# 107       PUMPKINS      NEW YORK  Conventional       bushel cartons
# 108       PUMPKINS      NEW YORK  Conventional  1 1/9 bushel crates
# 109       PUMPKINS      NEW YORK  Conventional  1 1/9 bushel crates
# 110       PUMPKINS      NEW YORK  Conventional  1 1/9 bushel crates
# 111       PUMPKINS      NEW YORK  Conventional  1 1/9 bushel crates
#
#          Variety Sub Variety        Date  Low Price  High Price  Mostly Low  \
# 0    HOWDEN TYPE         NaN  09/16/2017        140       150.0         140
# 1    HOWDEN TYPE         NaN  09/24/2016        150       150.0         150
# 2    HOWDEN TYPE         NaN  09/24/2016        150       150.0         150
# 3    HOWDEN TYPE         NaN  09/24/2016        150       160.0         150
# 4    HOWDEN TYPE         NaN  10/01/2016        140       140.0         140
# ..           ...         ...         ...        ...         ...         ...
# 107    MINIATURE         NaN  09/09/2017         32        32.0          32
# 108    MINIATURE  ROUND TYPE  10/08/2016         18        18.0          18
# 109    MINIATURE  ROUND TYPE  10/08/2016         18        18.0          18
# 110    MINIATURE  ROUND TYPE  10/15/2016         18        18.0          18
# 111    MINIATURE  ROUND TYPE  10/15/2016         18        18.0          18
#
#      ...  Environment Unit of Sale Quality Condition Appearance  Storage Crop  \
# 0    ...          NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 1    ...          NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 2    ...          NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 3    ...          NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 4    ...          NaN          NaN     NaN       NaN        NaN      NaN  NaN
# ..   ...          ...          ...     ...       ...        ...      ...  ...
# 107  ...          NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 108  ...          NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 109  ...          NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 110  ...          NaN          NaN     NaN       NaN        NaN      NaN  NaN
# 111  ...          NaN          NaN     NaN       NaN        NaN      NaN  NaN
#
#      Repack  Trans Mode  Grade
# 0     False         NaN    NaN
# 1     False         NaN    NaN
# 2     False         NaN    NaN
# 3     False         NaN    NaN
# 4     False         NaN    NaN
# ..      ...         ...    ...
# 107   False         NaN    NaN
# 108   False         NaN    NaN
# 109   False         NaN    NaN
# 110   False         NaN    NaN
# 111   False         NaN    NaN
#
# [674 rows x 25 columns]

# %% [markdown]
# ## Answer Some Questions
#
# Use `groupby()` and `agg()` to answer the following two questions:
#
# 1. What is the mean low and high prices for each type of unit of sale in the Northeast region? In the last lesson, we learned that a unit of sale could be something like a bin or individually.
# 2. What is the average number of pumpkins for each variety that came into terminal markets for the year by region? Pumpkin varieties include Howden and Fairytale pumpkins.

# %%
# Put your code here to find the mean low and high prices in the Northeast region for each type of unit of sale.
result.agg({'Low Price' : [ 'mean'], 'High Price' : ['mean']})
# Out:
#        Low Price  High Price
# mean  134.183976  150.671365

# %%
# Put your code here to find the average number of pumpkins coming into terminal markets of each variety.
result.agg({'City Name' : [ 'mean'], 'Variety' : ['mean']})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 2
#       1 # Put your code here to find the average number of pumpkins coming into terminal markets of each variety.
# ----> 2 result.agg({'City Name' : [ 'mean'], 'Variety' : ['mean']})
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:9342, in DataFrame.aggregate(self, func, axis, *args, **kwargs)
#    9339 relabeling, func, columns, order = reconstruct_func(func, **kwargs)
#    9341 op = frame_apply(self, func=func, axis=axis, args=args, kwargs=kwargs)
# -> 9342 result = op.agg()
#    9344 if relabeling:
#    9345     # This is to keep the order to columns occurrence unchanged, and also
#    9346     # keep the order of new columns occurrence unchanged
#    9347
#    9348     # For the return values of reconstruct_func, if relabeling is
#    9349     # False, columns and order will be None.
#    9350     assert columns is not None
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:776, in FrameApply.agg(self)
#     774 result = None
#     775 try:
# --> 776     result = super().agg()
#     777 except TypeError as err:
#     778     exc = TypeError(
#     779         "DataFrame constructor called with "
#     780         f"incompatible data and dtype: {err}"
#     781     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:172, in Apply.agg(self)
#     169     return self.apply_str()
#     171 if is_dict_like(arg):
# --> 172     return self.agg_dict_like()
#     173 elif is_list_like(arg):
#     174     # we require a list, but not a 'str'
#     175     return self.agg_list_like()
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:504, in Apply.agg_dict_like(self)
#     501     results = {key: colg.agg(how) for key, how in arg.items()}
#     502 else:
#     503     # key used for column selection and output
# --> 504     results = {
#     505         key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     506     }
#     508 # set the final keys
#     509 keys = list(arg.keys())
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:505, in <dictcomp>(.0)
#     501     results = {key: colg.agg(how) for key, how in arg.items()}
#     502 else:
#     503     # key used for column selection and output
#     504     results = {
# --> 505         key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     506     }
#     508 # set the final keys
#     509 keys = list(arg.keys())
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:4605, in Series.aggregate(self, func, axis, *args, **kwargs)
#    4602     func = dict(kwargs.items())
#    4604 op = SeriesApply(self, func, convert_dtype=False, args=args, kwargs=kwargs)
# -> 4605 result = op.agg()
#    4606 return result
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:1126, in SeriesApply.agg(self)
#    1125 def agg(self):
# -> 1126     result = super().agg()
#    1127     if result is None:
#    1128         f = self.f
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:175, in Apply.agg(self)
#     172     return self.agg_dict_like()
#     173 elif is_list_like(arg):
#     174     # we require a list, but not a 'str'
# --> 175     return self.agg_list_like()
#     177 if callable(arg):
#     178     f = com.get_cython_func(arg)
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:438, in Apply.agg_list_like(self)
#     436 # if we are empty
#     437 if not len(results):
# --> 438     raise ValueError("no results")
#     440 if len(failed_names) > 0:
#     441     warnings.warn(
#     442         depr_nuisance_columns_msg.format(failed_names),
#     443         FutureWarning,
#     444         stacklevel=find_stack_level(),
#     445     )
#
# ValueError: no results

# %% [markdown]
# ## Bonus Mission
#
# Try answering the same questions for the Midwest (Chicago, Detroit, and St. Louis) or the Southeast (Atlanta, Columbia, and Miami) regions.

# %%
# Try the bonus mission if you have time!
